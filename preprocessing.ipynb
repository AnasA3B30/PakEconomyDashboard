# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# This notebook is for EDA and preprocessing, handling nan's and type errors (obj dtype instead of int, etc.)
# There are 2 folders for data [Data, filteredData,], Data has a sub-folder Dealtwith
# All data files were in Data, each file was reviewed and processed using this notebook and then moved to dealtWith
# Processed files were moved to filteredData

# %%
sugar_mill_stocks = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/adam sugar mills stock 2002-2022.csv') # linux paths lol
sugar_mill_stocks #exploring sugar mill data because all company stocks files have the same format so this covers them
# Out:
#             Date   Open   High    Low  Close  Volume
# 0      1/30/2001   9.00   9.00   9.00   9.00    1000
# 1      2/26/2001   9.00   7.45   7.00   7.00    1500
# 2       3/2/2001   7.00   6.50   5.00   5.00    2500
# 3      3/12/2001   5.00   6.00   5.90   6.00    1000
# 4       4/2/2001   6.00   6.00   6.00   6.00       0
# ...          ...    ...    ...    ...    ...     ...
# 3224   11/4/2022  24.31  25.34  24.30  25.34    4000
# 3225   11/7/2022  25.79  25.79  25.49  25.50    2000
# 3226   11/8/2022  25.50  25.79  25.50  25.79   15000
# 3227  11/10/2022  25.10  25.73  25.10  25.73    1000
# 3228  11/11/2022  26.24  26.24  26.24  26.24     500
#
# [3229 rows x 6 columns]

# %%
sugar_mill_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3229 entries, 0 to 3228
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3229 non-null   object
#  1   Open    3229 non-null   float64
#  2   High    3229 non-null   float64
#  3   Low     3229 non-null   float64
#  4   Close   3229 non-null   float64
#  5   Volume  3229 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 151.5+ KB

# %%
sugar_mill_stocks.describe()
# Out:
#               Open         High          Low        Close         Volume
# count  3229.000000  3229.000000  3229.000000  3229.000000    3229.000000
# mean     24.921096    25.641072    24.887900    25.442738   18224.432332
# std      11.515636    11.509208    11.048261    11.122006   54478.645165
# min       0.000000     0.000000     0.000000     4.000000       0.000000
# 25%      17.000000    17.400000    17.000000    17.380000    1000.000000
# 50%      22.500000    22.950000    22.390000    22.650000    3000.000000
# 75%      32.750000    33.870000    32.510000    33.370000   12500.000000
# max      80.000000    82.090000    78.680000    79.680000  816500.000000

# %%
sugar_mill_stocks['Date']=pd.to_datetime(sugar_mill_stocks['Date']) # to create year, month, day columns

# %%
sugar_mill_stocks['Year']=sugar_mill_stocks['Date'].dt.year
sugar_mill_stocks['Month']=sugar_mill_stocks['Date'].dt.month
sugar_mill_stocks['Day']=sugar_mill_stocks['Date'].dt.day

# %%
sugar_mill_stocks
# Out:
#            Date   Open   High    Low  Close  Volume  Year  Month  Day
# 0    2001-01-30   9.00   9.00   9.00   9.00    1000  2001      1   30
# 1    2001-02-26   9.00   7.45   7.00   7.00    1500  2001      2   26
# 2    2001-03-02   7.00   6.50   5.00   5.00    2500  2001      3    2
# 3    2001-03-12   5.00   6.00   5.90   6.00    1000  2001      3   12
# 4    2001-04-02   6.00   6.00   6.00   6.00       0  2001      4    2
# ...         ...    ...    ...    ...    ...     ...   ...    ...  ...
# 3224 2022-11-04  24.31  25.34  24.30  25.34    4000  2022     11    4
# 3225 2022-11-07  25.79  25.79  25.49  25.50    2000  2022     11    7
# 3226 2022-11-08  25.50  25.79  25.50  25.79   15000  2022     11    8
# 3227 2022-11-10  25.10  25.73  25.10  25.73    1000  2022     11   10
# 3228 2022-11-11  26.24  26.24  26.24  26.24     500  2022     11   11
#
# [3229 rows x 9 columns]

# %%
years = np.arange(2001,2023) # value-month plots for years
for year in years:
    plot_data_raw = sugar_mill_stocks.loc[sugar_mill_stocks['Year']==year]
    plot_data_raw.sort_values('Day',inplace=True)
    plot_data = plot_data_raw.groupby('Month')[['Open','Low','High','Close',]].mean()
    volume = plot_data_raw.groupby('Month')['Volume'].sum()
    plt.figure(figsize=(18,15))
    plt.subplot(2,2,1)
    sns.lineplot(plot_data,marker='o')
    plt.title(year)
    plt.legend()
    plt.subplot(2,2,2)
    sns.barplot(plot_data)
    plt.title(f'Avg Yearly Values for {year}')
    plt.subplot(2,1,2)
    plt.title(f'Monthly volume traded for Year {year}')
    sns.barplot(volume)
    plt.show()
# Out:
# /tmp/ipykernel_3018/2868106682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_raw.sort_values('Day',inplace=True)
# /tmp/ipykernel_3018/2868106682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_raw.sort_values('Day',inplace=True)
# /tmp/ipykernel_3018/2868106682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_raw.sort_values('Day',inplace=True)
# ...

# %%
volume_grouped = sugar_mill_stocks.groupby('Year')['Volume'].sum() # find total volume traded by year
volume_grouped
# Out:
# Year
# 2001       39000
# 2002      532000
# 2003      118000
# 2004      279000
# 2005       49000
# 2006      409000
# 2007      940000
# 2008      348500
# 2009      200287
# 2010      394202
# 2011      312520
# 2012      302183
# 2013      474500
# 2014     5086000
# 2015     7196500
# 2016     9086000
# 2017    11903500
# 2018     7593000
# 2019     1223500
# 2020     2044000
# 2021     7200000
# 2022     3116000
# Name: Volume, dtype: int64

# %%
plt.figure(figsize=(20,7))
sns.barplot(volume_grouped) # plotting total value against years
# Out:
# <Axes: xlabel='Year', ylabel='Volume'>

# %%
kse_100 = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Stock Exchange KSE 100 PK.csv')

# %%
kse_100
# Out:
#            Date       Open       High        Low      Close   Change  \
# 0     23-Feb-21  31,722.16  31,800.90  31,597.31  31,626.19   -21.38
# 1     22-Feb-21  31,874.78  31,958.58  31,612.55  31,647.57  -203.61
# 2     19-Feb-21  31,748.75  31,904.30  31,749.43  31,851.18    91.36
# 3     18-Feb-21  32,049.85  32,104.67  31,745.72  31,759.82  -288.86
# 4     17-Feb-21  32,166.21  32,390.77  32,044.01  32,048.68   -93.15
# ...         ...        ...        ...        ...        ...      ...
# 3216  28-Feb-08  10,688.98  10,724.21  10,655.23  10,704.15    39.79
# 3217  27-Feb-08  10,670.68  10,732.92  10,623.36  10,664.36    -3.99
# 3218  26-Feb-08  10,596.40  10,668.35  10,578.01  10,668.35    79.51
# 3219  25-Feb-08  10,625.66  10,709.06  10,579.49  10,588.84   -18.45
# 3220  22-Feb-08  10,634.22  10,635.42  10,546.38  10,607.29        0
#
#            Volume
# 0     718,191,025
# 1     721,952,658
# 2     694,795,084
# 3     577,837,595
# 4     701,658,181
# ...           ...
# ...

# %%
kse_100['Date']=pd.to_datetime(kse_100['Date'])
kse_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3221 non-null   datetime64[ns]
#  1   Open    3221 non-null   object
#  2   High    3221 non-null   object
#  3   Low     3221 non-null   object
#  4   Close   3221 non-null   object
#  5   Change  3221 non-null   object
#  6   Volume  3221 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 176.3+ KB
# /tmp/ipykernel_3018/2613208004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   kse_100['Date']=pd.to_datetime(kse_100['Date'])

# %%
kse_100['Year'] = kse_100['Date'].dt.year
kse_100['Month'] = kse_100['Date'].dt.month
kse_100['Day'] = kse_100['Date'].dt.day

# %%
kse_100
# Out:
#            Date       Open       High        Low      Close   Change  \
# 3220 2008-02-22  10,634.22  10,635.42  10,546.38  10,607.29        0
# 3219 2008-02-25  10,625.66  10,709.06  10,579.49  10,588.84   -18.45
# 3154 2008-05-29   8,511.62   8,788.07   8,396.78   8,758.19   -27.22
# 3155 2008-05-28   9,208.22   9,248.94   8,764.99   8,785.41  -394.82
# 3156 2008-05-27   8,987.83   9,180.23   8,848.21   9,180.23   160.93
# ...         ...        ...        ...        ...        ...      ...
# 22   2021-01-21  31,723.52  32,087.84  31,722.41  31,913.85   191.44
# 21   2021-01-22  31,929.64  31,975.96  31,741.84  31,840.92   -72.94
# 12   2021-02-04  32,358.58  32,602.03  32,302.37  32,386.09    27.13
# 13   2021-02-03  32,187.71  32,451.23  32,167.97  32,358.96   190.99
# 14   2021-02-02  32,086.81  32,183.85  31,985.60  32,167.97   166.89
#
#            Volume  Year  Month  Day
# 3220  313,082,688  2008      2   22
# 3219  273,149,184  2008      2   25
# ...

# %%
kse_100=kse_100.sort_values('Year') #re-ran the upper cell to see changes

# %%
kse_100['Open'] = kse_100['Open'].apply(lambda x : x.replace(',','')).astype(float) # convert from object dtype to float

# %%
kse_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3221 entries, 3220 to 14
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3221 non-null   datetime64[ns]
#  1   Open    3221 non-null   float64
#  2   High    3221 non-null   object
#  3   Low     3221 non-null   object
#  4   Close   3221 non-null   object
#  5   Change  3221 non-null   object
#  6   Volume  3221 non-null   object
#  7   Year    3221 non-null   int32
#  8   Month   3221 non-null   int32
#  9   Day     3221 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(3), object(5)
# memory usage: 239.1+ KB

# %%
kse_100['Close'] = kse_100['Close'].apply(lambda x : x.replace(',','')).astype(float)
kse_100['High'] = kse_100['High'].apply(lambda x : x.replace(',','')).astype(float)
kse_100['Low'] = kse_100['Low'].apply(lambda x : x.replace(',','')).astype(float)
kse_100['Change'] = kse_100['Change'].apply(lambda x : x.replace(',','')).astype(float)
kse_100['Volume'] = kse_100['Volume'].apply(lambda x : x.replace(',','')).astype(float)

# %%
kse_100.reset_index(inplace=True)

# %%
kse_100
# Out:
#       index       Date      Open      High       Low     Close  Change  \
# 0      3220 2008-02-22  10634.22  10635.42  10546.38  10607.29    0.00
# 1      3219 2008-02-25  10625.66  10709.06  10579.49  10588.84  -18.45
# 2      3154 2008-05-29   8511.62   8788.07   8396.78   8758.19  -27.22
# 3      3155 2008-05-28   9208.22   9248.94   8764.99   8785.41 -394.82
# 4      3156 2008-05-27   8987.83   9180.23   8848.21   9180.23  160.93
# ...     ...        ...       ...       ...       ...       ...     ...
# 3216     22 2021-01-21  31723.52  32087.84  31722.41  31913.85  191.44
# 3217     21 2021-01-22  31929.64  31975.96  31741.84  31840.92  -72.94
# 3218     12 2021-02-04  32358.58  32602.03  32302.37  32386.09   27.13
# 3219     13 2021-02-03  32187.71  32451.23  32167.97  32358.96  190.99
# 3220     14 2021-02-02  32086.81  32183.85  31985.60  32167.97  166.89
#
#            Volume  Year  Month  Day
# 0     313082688.0  2008      2   22
# 1     273149184.0  2008      2   25
# ...

# %%
kse_100=kse_100.drop(columns='index') # I have no idea why this is happening lol

# %%
kse_100.to_csv('KSE100.csv')

# %%
paths = [
    r'/home/anas/Desktop/Economy Report/data/adam sugar mills stock 2002-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/allied bank stock 2005-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/askari bank stock 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/attock petroleum 2005-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/DG Khan Cement 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/Engro Fertilizers Stock 2014-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/Fatima Enterprises Stock 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/Fauji fertilizer stock 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/Faysal Bank stock 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/habib bank stock 2007-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/honda stock 2001-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/Hum network stock 2007-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/JS bank 2007-2022.csv',
    r'/home/anas/Desktop/Economy Report/data/k electric stock.csv',
    r'/home/anas/Desktop/Economy Report/data/NBP stock 2001-2022.csv',
]


for path in paths:
    path = path.split(r'/')[-1] #verifying the results
    print(path)
# Out:
# adam sugar mills stock 2002-2022.csv
# allied bank stock 2005-2022.csv
# askari bank stock 2001-2022.csv
# attock petroleum 2005-2022.csv
# DG Khan Cement 2001-2022.csv
# Engro Fertilizers Stock 2014-2022.csv
# Fatima Enterprises Stock 2001-2022.csv
# Fauji fertilizer stock 2001-2022.csv
# Faysal Bank stock 2001-2022.csv
# habib bank stock 2007-2022.csv
# honda stock 2001-2022.csv
# Hum network stock 2007-2022.csv
# JS bank 2007-2022.csv
# k electric stock.csv
# NBP stock 2001-2022.csv

# %%
for path in paths: # after this was finished executing, the involved files were moved to 'Dealt With' folder
    df = pd.read_csv(path)
    name = path.split(r'/')[-1] #extracting unique identifiers from the files
    
    try: # assuming all are like sugar mills stocks BUT there could be some differences

        df['Date'] = pd.to_datetime(df['Date']) #extract year, month and day
        df['Year'] = df['Date'].dt.year
        df['Month'] = df['Date'].dt.month
        df['Day'] = df['Date'].dt.day
        df=df.sort_values('Year') 
        print(df.info()) # to see column dtypes from each file
        df['Open'] = df['Open'].apply(lambda x : x.replace(',','')).astype(float) 
        df['Close'] = df['Close'].apply(lambda x : x.replace(',','')).astype(float)
        df['Low'] = df['Low'].apply(lambda x : x.replace(',','')).astype(float)
        df['Change'] = df['Change'].apply(lambda x : x.replace(',','')).astype(float)
        df['Volume'] = df['Volume'].apply(lambda x : x.replace(',','')).astype(float)

    except:
        print('Some issues converting the columns.')
    df.to_csv(name) # refined csv, all were moved to filteredData
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3229 entries, 0 to 3189
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3229 non-null   datetime64[ns]
#  1   Open    3229 non-null   float64
#  2   High    3229 non-null   float64
#  3   Low     3229 non-null   float64
#  4   Close   3229 non-null   float64
#  5   Volume  3229 non-null   int64
#  6   Year    3229 non-null   int32
#  7   Month   3229 non-null   int32
#  8   Day     3229 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(3), int64(1)
# memory usage: 214.4 KB
# None
# Some issues converting the columns.
# <class 'pandas.core.frame.DataFrame'>
# Index: 4170 entries, 32 to 4132
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4170 non-null   datetime64[ns]
#  1   Open    4170 non-null   float64
#  2   High    4170 non-null   float64
# ...

# %%
df = pd.read_csv(r'/home/anas/Desktop/Economy Report/k electric stock.csv') #KSE100 had column 'date' instead of 'Date' and was skipped over

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1091 non-null   int64
#  1   date        1091 non-null   object
#  2   open        1091 non-null   float64
#  3   high        1091 non-null   float64
#  4   low         1091 non-null   float64
#  5   close       1091 non-null   float64
#  6   volume      1091 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 59.8+ KB

# %%
df['Date']=pd.to_datetime(df['date'])

# %%
df=df.drop(columns='date')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df=df.sort_values('Year')

# %%
df
# Out:
#       Unnamed: 0  open  high   low  close    volume       Date  Year  Month  \
# 0              0  6.30  6.31  6.17   6.21   2280500 2018-01-01  2018      1
# 1              1  6.13  6.54  6.13   6.49  18297000 2018-01-02  2018      1
# 2              2  6.49  6.99  6.40   6.75  47374000 2018-01-03  2018      1
# 19            19  6.76  7.07  6.62   6.89  39164000 2018-01-26  2018      1
# 20            20  6.85  6.89  6.71   6.73   2129000 2018-01-29  2018      1
# ...          ...   ...   ...   ...    ...       ...        ...   ...    ...
# 1077        1077  2.69  2.69  2.53   2.64   3209000 2022-05-12  2022      5
# 1090        1090  2.64  2.70  2.61   2.62   1674000 2022-05-31  2022      5
# 1059        1059  2.94  2.95  2.88   2.93   6916000 2022-04-08  2022      4
# 1076        1076  2.70  2.70  2.51   2.60   6320500 2022-05-11  2022      5
# 1075        1075  2.69  2.73  2.65   2.70   6111500 2022-05-10  2022      5
#
#       Day
# 0       1
# 1       2
# 2       3
# ...

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#       open  high   low  close    volume       Date  Year  Month  Day
# 0     6.30  6.31  6.17   6.21   2280500 2018-01-01  2018      1    1
# 1     6.13  6.54  6.13   6.49  18297000 2018-01-02  2018      1    2
# 2     6.49  6.99  6.40   6.75  47374000 2018-01-03  2018      1    3
# 19    6.76  7.07  6.62   6.89  39164000 2018-01-26  2018      1   26
# 20    6.85  6.89  6.71   6.73   2129000 2018-01-29  2018      1   29
# ...    ...   ...   ...    ...       ...        ...   ...    ...  ...
# 1077  2.69  2.69  2.53   2.64   3209000 2022-05-12  2022      5   12
# 1090  2.64  2.70  2.61   2.62   1674000 2022-05-31  2022      5   31
# 1059  2.94  2.95  2.88   2.93   6916000 2022-04-08  2022      4    8
# 1076  2.70  2.70  2.51   2.60   6320500 2022-05-11  2022      5   11
# 1075  2.69  2.73  2.65   2.70   6111500 2022-05-10  2022      5   10
#
# [1091 rows x 9 columns]

# %%
df.to_csv('K Electric Stock.csv') # file was moved to filteredData

# %%
exchange_rates = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Exchange rates.csv')

# %%
exchange_rates
# Out:
#                  CURRENCY  Unnamed: 1 Australian Dollar Bahraini Dinar  \
# 0    Aug 1947 to Jun 1949         NaN               ...            ...
# 1    Jul 1949 to Jun 1952         NaN               ...            ...
# 2    Jul 1952 to Jul 1955         NaN               ...            ...
# 3    Aug 1955 to Dec 1956         NaN               ...            ...
# 4                     Jan      1957.0            5.3421            ...
# ..                    ...         ...               ...            ...
# 755                August      2019.0          106.9197       417.6304
# 756             September      2019.0          106.1202       412.8507
# 757               October      2019.0          105.8437       412.2000
# 758              November      2019.0          105.9925       410.7237
# 759              December      2019.0          106.4443       409.6415
#
#     Canadian Dollar Chinese Yuan Danish Krone Hongkong Dollar Japnese Yen  \
# ...

# %%
exchange_rates = exchange_rates[114:]

# %%
exchange_rates
# Out:
#       CURRENCY  Unnamed: 1 Australian Dollar Bahraini Dinar Canadian Dollar  \
# 114        Mar      1966.0            5.3421        10.0164          4.4320
# 115        Apr      1966.0            5.3421        10.0164          4.4287
# 116        May      1966.0            5.3421        10.0164          4.4299
# 117        Jun      1966.0            5.3421        10.0164          4.4307
# 118        Jul      1966.0            5.3421        10.0164          4.4378
# ..         ...         ...               ...            ...             ...
# 755     August      2019.0          106.9197       417.6304        119.0339
# 756  September      2019.0          106.1202       412.8507        117.7828
# 757    October      2019.0          105.8437       412.2000        118.1283
# 758   November      2019.0          105.9925       410.7237        117.3246
# 759   December      2019.0          106.4443       409.6415        117.4770
#
# ...

# %%
exchange_rates=exchange_rates.reset_index()

# %%
exchange_rates
# Out:
#      index   CURRENCY  Unnamed: 1 Australian Dollar Bahraini Dinar  \
# 0      114        Mar      1966.0            5.3421        10.0164
# 1      115        Apr      1966.0            5.3421        10.0164
# 2      116        May      1966.0            5.3421        10.0164
# 3      117        Jun      1966.0            5.3421        10.0164
# 4      118        Jul      1966.0            5.3421        10.0164
# ..     ...        ...         ...               ...            ...
# 641    755     August      2019.0          106.9197       417.6304
# 642    756  September      2019.0          106.1202       412.8507
# 643    757    October      2019.0          105.8437       412.2000
# 644    758   November      2019.0          105.9925       410.7237
# 645    759   December      2019.0          106.4443       409.6415
#
#     Canadian Dollar Chinese Yuan Danish Krone Hongkong Dollar Japnese Yen  \
# 0            4.4320       1.9375       0.6905             ...      0.0132
# ...

# %%
exchange_rates = exchange_rates.drop(columns='index')

# %%
exchange_rates
# Out:
#       CURRENCY  Unnamed: 1 Australian Dollar Bahraini Dinar Canadian Dollar  \
# 0          Mar      1966.0            5.3421        10.0164          4.4320
# 1          Apr      1966.0            5.3421        10.0164          4.4287
# 2          May      1966.0            5.3421        10.0164          4.4299
# 3          Jun      1966.0            5.3421        10.0164          4.4307
# 4          Jul      1966.0            5.3421        10.0164          4.4378
# ..         ...         ...               ...            ...             ...
# 641     August      2019.0          106.9197       417.6304        119.0339
# 642  September      2019.0          106.1202       412.8507        117.7828
# 643    October      2019.0          105.8437       412.2000        118.1283
# 644   November      2019.0          105.9925       410.7237        117.3246
# 645   December      2019.0          106.4443       409.6415        117.4770
#
# ...

# %%
exchange_rates['Year'] = exchange_rates['Unnamed: 1']
exchange_rates = exchange_rates.drop(columns=['Unnamed: 1','Unnamed: 24'])
exchange_rates
# Out:
#       CURRENCY Australian Dollar Bahraini Dinar Canadian Dollar Chinese Yuan  \
# 0          Mar            5.3421        10.0164          4.4320       1.9375
# 1          Apr            5.3421        10.0164          4.4287       1.9375
# 2          May            5.3421        10.0164          4.4299       1.9375
# 3          Jun            5.3421        10.0164          4.4307       1.9375
# 4          Jul            5.3421        10.0164          4.4378       1.9375
# ..         ...               ...            ...             ...          ...
# 641     August          106.9197       417.6304        119.0339      22.3747
# 642  September          106.1202       412.8507        117.7828      21.9424
# 643    October          105.8437       412.2000        118.1283      21.9754
# 644   November          105.9925       410.7237        117.3246      22.1311
# 645   December          106.4443       409.6415        117.4770      22.0815
#
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CURRENCY            646 non-null    object
#  1   Australian Dollar   646 non-null    object
#  2   Bahraini Dinar      646 non-null    object
#  3   Canadian Dollar     646 non-null    object
#  4   Chinese Yuan        646 non-null    object
#  5   Danish Krone        646 non-null    object
#  6   Hongkong Dollar     646 non-null    object
#  7   Japnese Yen         646 non-null    object
#  8   Kuwaiti Dinar       646 non-null    object
#  9   Malaysian Ringgit   646 non-null    object
#  10  New Zealand Dollar  646 non-null    object
#  11  Norwegian Krone     646 non-null    object
#  12  Omani Rial          646 non-null    object
#  13  Qatari Rial         646 non-null    object
#  14  Singaporian Dollar  646 non-null    object
# ...

# %%
exchange_rates.Year.unique()
# Out:
# array([1966., 1967., 1968., 1969., 1970., 1971., 1972., 1973., 1974.,
#        1975., 1976., 1977., 1978., 1979., 1980., 1981., 1982., 1983.,
#        1984., 1985., 1986., 1987., 1988., 1989., 1990., 1991., 1992.,
#        1993., 1994., 1995., 1996., 1997., 1998., 1999., 2000., 2001.,
#        2002., 2003., 2004., 2005., 2006., 2007., 2008., 2009., 2010.,
#        2011., 2012., 2013., 2014., 2015., 2016., 2017., 2018., 2019.])

# %%
column = exchange_rates.columns

# %%
for col in column[1:]:
    exchange_rates[col] = pd.to_numeric(exchange_rates[col], errors='coerce')
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CURRENCY            646 non-null    object
#  1   Australian Dollar   646 non-null    float64
#  2   Bahraini Dinar      646 non-null    float64
#  3   Canadian Dollar     646 non-null    float64
#  4   Chinese Yuan        646 non-null    float64
#  5   Danish Krone        646 non-null    float64
#  6   Hongkong Dollar     456 non-null    float64
#  7   Japnese Yen         646 non-null    float64
#  8   Kuwaiti Dinar       639 non-null    float64
#  9   Malaysian Ringgit   646 non-null    float64
#  10  New Zealand Dollar  646 non-null    float64
#  11  Norwegian Krone     646 non-null    float64
#  12  Omani Rial          646 non-null    float64
#  13  Qatari Rial         646 non-null    float64
#  14  Singaporian Dollar  646 non-null    float64
# ...

# %%
exchange_rates.to_csv('exhange_rates.csv')

# %%
zakat = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Dealt With/disbursement of zakat and benefeciaries in punjab.csv')

# %%
zakat
# Out:
#                                             Head  Disbursement 2018-19  \
# 0                                          Total                  3673
# 1                               Guzara Allowance                  1620
# 2                  Educational Stipend (General)                   105
# 3                Educational Stipend (Technical)                   910
# 4                                  Deeni Madaris                   113
# 5                                    Health Care                    96
# 6                               Leprosy Patients                     1
# 7                                           SEEP                    87
# 8                      Marriage Grant/Assistance                   109
# 9                                      Eid Grant                   141
# 10                              Guzara for Blind                   102
# 11  Provincial/National Level Health Institution                   321
# ...

# %%
zakat.info() #this one needed manual work, so far as i know, two rows were not where they were supposed to be as shown above
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Head                   14 non-null     object
#  1   Disbursement 2018-19   14 non-null     int64
#  2   Beneficiaries 2018-19  14 non-null     int64
#  3   Disbursement 2019-20   14 non-null     int64
#  4   Beneficiaries 2019-20  14 non-null     int64
#  5   Disbursement 2020-21   14 non-null     int64
#  6   Beneficiaries 2020-21  14 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 916.0+ bytes

# %%
employed_percentage = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Employed percentage distribution by employment status and sex in PK.csv')

# %%
employed_percentage
# Out:
#              Employment Status  Total 2014-15  Male 2014-15  Female 2014-15  \
# 0                        Total          100.0         100.0           100.0
# 1                    Employers            1.4           1.7             0.1
# 2          Own account workers           36.1          40.9            20.4
# 3  Contributing family workers           23.8          14.5            54.5
# 4                    Employees           38.7          42.9            24.9
#
#    Total 2017-18  Male 2017-18  Female 2017-18
# 0          100.0         100.0           100.0
# 1            1.4           1.7             0.1
# 2           34.8          39.1            19.5
# 3           21.4          12.9            51.9
# 4           42.4          46.3            28.5

# %%
employed_percentage.info() #checks out
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employment Status  5 non-null      object
#  1   Total 2014-15      5 non-null      float64
#  2   Male 2014-15       5 non-null      float64
#  3   Female 2014-15     5 non-null      float64
#  4   Total 2017-18      5 non-null      float64
#  5   Male 2017-18       5 non-null      float64
#  6   Female 2017-18     5 non-null      float64
# dtypes: float64(6), object(1)
# memory usage: 412.0+ bytes

# %%
employment_and_wages = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Employment and wages 2006-2022.csv')

# %%
employment_and_wages
# Out:
#    Year\n(  July-June  )/ Month  No. of Reporting Mills  \
# 0                       2006-07                     288
# 1                       2007-08                     288
# 2                       2008-09                     288
# 3                       2009-10                     288
# 4                       2010-11                     295
# 5                       2011-12                     295
# 6                       2012-13                     280
# 7                       2013-14                     281
# 8                       2014-15                     289
# 9                       2015-16                     289
# 10                      2016-17                     298
# 11                      2017-18                     299
# 12                      2018-19                     299
# 13                      2019-20                     299
# 14                      2020-21                     285
# 15                      2021-22                     285
# ...

# %%
employment_and_wages.info() #workable? have to fix the names though
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Year
# (  July-June  )/ Month                          35 non-null     object
#  1   No. of Reporting Mills                               35 non-null     int64
#  2   Total E M P L O Y M E N T  (Nos.)*                   35 non-null     int64
#  3   Production Workers E M P L O Y M E N T  (Nos.)*      35 non-null     int64
#  4   Office Staff E M P L O Y M E N T  (Nos.)*            35 non-null     int64
#  5   Total WAGES/SALARIES   (Thousand  Rs.)               35 non-null     int64
#  6   Production Workers WAGES/SALARIES   (Thousand  Rs.)  35 non-null     int64
#  7   Office Staff WAGES/SALARIES   (Thousand  Rs.)        35 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.3+ KB

# %%
employment_and_wages['Total Employment'] = employment_and_wages['Total E M P L O Y M E N T  (Nos.)*']
employment_and_wages['Production Workers Employments'] = employment_and_wages['Production Workers E M P L O Y M E N T  (Nos.)*']
employment_and_wages['Office Staff Emplyments'] = employment_and_wages['Office Staff E M P L O Y M E N T  (Nos.)*']
employment_and_wages['Total Wages (thousand Rs.)'] = employment_and_wages['Total WAGES/SALARIES   (Thousand  Rs.)']
employment_and_wages['Production Worker Wages (thousand Rs.)'] = employment_and_wages['Production Workers WAGES/SALARIES   (Thousand  Rs.)']
employment_and_wages['Offiice Staff Wages (thousand Rs.)'] = employment_and_wages['Office Staff WAGES/SALARIES   (Thousand  Rs.)']

# %%
employment_and_wages
# Out:
#    Year\n(  July-June  )/ Month  No. of Reporting Mills  \
# 0                       2006-07                     288
# 1                       2007-08                     288
# 2                       2008-09                     288
# 3                       2009-10                     288
# 4                       2010-11                     295
# 5                       2011-12                     295
# 6                       2012-13                     280
# 7                       2013-14                     281
# 8                       2014-15                     289
# 9                       2015-16                     289
# 10                      2016-17                     298
# 11                      2017-18                     299
# 12                      2018-19                     299
# 13                      2019-20                     299
# 14                      2020-21                     285
# 15                      2021-22                     285
# ...

# %%
employment_and_wages = employment_and_wages.drop(columns=['Total E M P L O Y M E N T  (Nos.)*','Production Workers E M P L O Y M E N T  (Nos.)*','Office Staff E M P L O Y M E N T  (Nos.)*','Total WAGES/SALARIES   (Thousand  Rs.)','Production Workers WAGES/SALARIES   (Thousand  Rs.)','Office Staff WAGES/SALARIES   (Thousand  Rs.)'])

# %%
employment_and_wages
# Out:
#    Year\n(  July-June  )/ Month  No. of Reporting Mills  Total Employment  \
# 0                       2006-07                     288            183201
# 1                       2007-08                     288            176643
# 2                       2008-09                     288            162984
# 3                       2009-10                     288            168727
# 4                       2010-11                     295            166718
# 5                       2011-12                     295            163535
# 6                       2012-13                     280            169697
# 7                       2013-14                     281            172129
# 8                       2014-15                     289            170528
# 9                       2015-16                     289            164049
# 10                      2016-17                     298            165251
# 11                      2017-18                     299            161727
# ...

# %%
employment_and_wages.to_csv('Employment and Wages.csv')

# %%
export_by_areas = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/exports by areas and countries territories 2020-2021.csv')

# %%
export_by_areas
# Out:
#    Territories/Countries   Nov., 2021 Cumulative From July,2021   Nov., 2020  \
# 0          GRAND  TOTALS  502,009,454             2,072,145,073  345,639,504
# 1          LATIN AMERICA      421,890                 1,895,054      208,899
# 2    Antigua and Barbuda        5,706                    11,560          NaN
# 3                  Aruba          NaN                       777        2,057
# 4                Bahamas        7,130                    23,670        3,346
# ..                   ...          ...                       ...          ...
# 57   Republic of Moldova           68                    14,999        8,058
# 58               Romania      884,253                 3,737,223      650,854
# 59    Russian Federation    2,507,050                 8,797,680    1,649,175
# 60    Slovakia/Slovak R.      254,419                 1,711,681      250,314
# 61               Ukraine      731,034                 3,500,281      885,437
#
#    Cumulative FromJuly,2020
# ...

# %%
l = list(zakat['Head'])
l2 = list(zakat['Beneficiaries 2018-19'])

# %%
d = dict(zip(l,l2))
d
# Out:
# {'Total': 447650,
#  'Guzara Allowance': 134949,
#  'Educational Stipend (General)': 15629,
#  'Educational Stipend (Technical)': 37240,
#  'Deeni Madaris': 21775,
#  'Health Care': 17665,
#  'Leprosy Patients': 66,
#  'SEEP': 1745,
#  'Marriage Grant/Assistance': 5435,
#  'Eid Grant': 136658,
#  'Guzara for Blind': 5650,
#  'Provincial/National Level Health Institution': 66361,
#  'Social Rehabilitation': 4477,
#  'Guzara for Covid-19': 0}

# %%
e = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/exports by areas and countries territories 2020-2021.csv')

# %%
e
# Out:
#    Territories/Countries   Nov., 2021 Cumulative From July,2021   Nov., 2020  \
# 0          GRAND  TOTALS  502,009,454             2,072,145,073  345,639,504
# 1          LATIN AMERICA      421,890                 1,895,054      208,899
# 2    Antigua and Barbuda        5,706                    11,560          NaN
# 3                  Aruba          NaN                       777        2,057
# 4                Bahamas        7,130                    23,670        3,346
# ..                   ...          ...                       ...          ...
# 57   Republic of Moldova           68                    14,999        8,058
# 58               Romania      884,253                 3,737,223      650,854
# 59    Russian Federation    2,507,050                 8,797,680    1,649,175
# 60    Slovakia/Slovak R.      254,419                 1,711,681      250,314
# 61               Ukraine      731,034                 3,500,281      885,437
#
#    Cumulative FromJuly,2020
# ...

# %%
gdp_sector = pd.read_csv(r'/home/anas/Desktop/Economy Report/filteredData/gdpSector.csv')

# %%
gdp_sector
# Out:
#      Unnamed: 0  Year       Sector                 Product         Amount  \
# 0             0  1999  Agriculture         Important Crops   322835000000
# 1             1  2000  Agriculture         Important Crops   315037000000
# 2             2  2001  Agriculture         Important Crops   296705000000
# 3             3  2002  Agriculture         Important Crops   344271000000
# 4             4  2003  Agriculture         Important Crops   420938000000
# ..          ...   ...          ...                     ...            ...
# 355         355  2014     Services  Other Private Services  2375495000000
# 356         356  2015     Services  Other Private Services  2618997000000
# 357         357  2016     Services  Other Private Services  2958640000000
# 358         358  2017     Services  Other Private Services  3333280000000
# 359         359  2018     Services  Other Private Services  3812369000000
#
#      Note: Value in Millions
# 0                        NaN
# ...

# %%
gdp_sector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               360 non-null    int64
#  1   Year                     360 non-null    int64
#  2   Sector                   360 non-null    object
#  3   Product                  360 non-null    object
#  4   Amount                   360 non-null    int64
#  5   Note: Value in Millions  0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 17.0+ KB

# %%
gdp_sector['Amount'] = gdp_sector['Amount']*1000000 #accidentally ran twice

# %%
gdp_sector
# Out:
#      Unnamed: 0  Year       Sector                 Product  \
# 0             0  1999  Agriculture         Important Crops
# 1             1  2000  Agriculture         Important Crops
# 2             2  2001  Agriculture         Important Crops
# 3             3  2002  Agriculture         Important Crops
# 4             4  2003  Agriculture         Important Crops
# ..          ...   ...          ...                     ...
# 355         355  2014     Services  Other Private Services
# 356         356  2015     Services  Other Private Services
# 357         357  2016     Services  Other Private Services
# 358         358  2017     Services  Other Private Services
# 359         359  2018     Services  Other Private Services
#
#                   Amount  Note: Value in Millions
# 0     322835000000000000                      NaN
# 1     315037000000000000                      NaN
# 2     296705000000000000                      NaN
# 3     344271000000000000                      NaN
# ...

# %%
gdp_sector.to_csv('gdpSector.csv')

# %%
gdp_sector['Year'].unique()
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
gdp_sector['Sector'].unique()
# Out:
# array(['Agriculture', 'Industrial', 'Services'], dtype=object)

# %%
gdp_sector['Product'].unique()
# Out:
# array(['Important Crops', 'Other crops', 'Cotton Grinning', 'Livestock',
#        'Forestry', 'Fishing', 'Mining and Quarrying',
#        'Large Scale Manufacturing', 'Small Scale Manufacturing',
#        'Slaughtering',
#        'Electricity generation & distribution and Gas distribution',
#        'Construction', 'Wholesale & Retail Trade',
#        'Transport, Storage and Communication', 'Finance and Insurance',
#        'Housing Services', 'General Governmental Services',
#        'Other Private Services'], dtype=object)

# %%
gdp_sector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               360 non-null    int64
#  1   Year                     360 non-null    int64
#  2   Sector                   360 non-null    object
#  3   Product                  360 non-null    object
#  4   Amount                   360 non-null    int64
#  5   Note: Value in Millions  0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 17.0+ KB

# %%
gdp_sector_d = gdp_sector[gdp_sector['Year']==2000]
gdp_sector_d.groupby('Sector')['Amount'].sum()['Agriculture']
# Out:
# np.int64(1119795000000)

# %%
gdp_sector_trend = gdp_sector[gdp_sector['Sector']=='Industrial'].groupby('Year')['Amount'].sum()
gdp_sector_trend
# Out:
# Year
# 1999     744651000000
# 2000     831934000000
# 2001     869622000000
# 2002     966269000000
# 2003    1215555000000
# 2004    1419763000000
# 2005    1616157000000
# 2006    1846217000000
# 2007    2312375000000
# 2008    2533221000000
# 2009    2931695000000
# 2010    3746997000000
# 2011    4269666000000
# 2012    4525694000000
# 2013    5040094000000
# 2014    5239146000000
# 2015    5308368000000
# 2016    5683546000000
# 2017    6226688000000
# 2018    7275304000000
# Name: Amount, dtype: int64

# %%
sns.lineplot(gdp_sector_trend)
gdp_sector_trend= dict(gdp_sector_trend)
gdp_sector_trend
# Out:
# {1999: np.int64(744651000000),
#  2000: np.int64(831934000000),
#  2001: np.int64(869622000000),
#  2002: np.int64(966269000000),
#  2003: np.int64(1215555000000),
#  2004: np.int64(1419763000000),
#  2005: np.int64(1616157000000),
#  2006: np.int64(1846217000000),
#  2007: np.int64(2312375000000),
#  2008: np.int64(2533221000000),
#  2009: np.int64(2931695000000),
#  2010: np.int64(3746997000000),
#  2011: np.int64(4269666000000),
#  2012: np.int64(4525694000000),
#  2013: np.int64(5040094000000),
#  2014: np.int64(5239146000000),
#  2015: np.int64(5308368000000),
#  2016: np.int64(5683546000000),
#  2017: np.int64(6226688000000),
#  2018: np.int64(7275304000000)}

# %%
inflation = pd.read_csv(r'/home/anas/Desktop/Economy Report/data/Inflation rate in asia and pacific-asian development.csv')

# %%
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RegionalMember       371 non-null    object
#  1   Year                 371 non-null    object
#  2   Inflation            365 non-null    float64
#  3   Unit of Measurement  371 non-null    object
#  4    Subregion           357 non-null    object
#  5    Country Code        322 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 17.5+ KB

# %%
inflation = inflation.dropna().reset_index()

# %%
inflation
# Out:
#      index RegionalMember           Year  Inflation Unit of Measurement  \
# 0       21        Armenia           2018        2.5                   %
# 1       22        Armenia           2019        1.4                   %
# 2       23        Armenia           2020        1.2                   %
# 3       24        Armenia           2021        7.2                   %
# 4       25        Armenia           2022        8.6                   %
# ..     ...            ...            ...        ...                 ...
# 311    366        Vanuatu           2020        5.3                   %
# 312    367        Vanuatu           2021        2.3                   %
# 313    368        Vanuatu           2022        4.8                   %
# 314    369        Vanuatu  2023 forecast        4.0                   %
# 315    370        Vanuatu  2024 forecast        3.0                   %
#
#         Subregion  Country Code
# 0    Central Asia           ARM
# 1    Central Asia           ARM
# ...

# %%
inflation = inflation.drop(columns='index')
inflation['Year'] = inflation['Year'].apply(lambda x: x.split(' ')[0])
inflation
# Out:
#     RegionalMember  Year  Inflation Unit of Measurement     Subregion  \
# 0          Armenia  2018        2.5                   %  Central Asia
# 1          Armenia  2019        1.4                   %  Central Asia
# 2          Armenia  2020        1.2                   %  Central Asia
# 3          Armenia  2021        7.2                   %  Central Asia
# 4          Armenia  2022        8.6                   %  Central Asia
# ..             ...   ...        ...                 ...           ...
# 311        Vanuatu  2020        5.3                   %   The Pacific
# 312        Vanuatu  2021        2.3                   %   The Pacific
# 313        Vanuatu  2022        4.8                   %   The Pacific
# 314        Vanuatu  2023        4.0                   %   The Pacific
# 315        Vanuatu  2024        3.0                   %   The Pacific
#
#      Country Code
# 0             ARM
# 1             ARM
# 2             ARM
# 3             ARM
# 4             ARM
# ...

# %%
inflation['Year'] = inflation['Year'].astype(int)
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RegionalMember       316 non-null    object
#  1   Year                 316 non-null    int64
#  2   Inflation            316 non-null    float64
#  3   Unit of Measurement  316 non-null    object
#  4    Subregion           316 non-null    object
#  5    Country Code        316 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 14.9+ KB

# %%
inflation['Country Code'] = inflation[' Country Code']
inflation = inflation.drop(columns=[' Subregion',' Country Code'])
inflation
# Out:
#     RegionalMember  Year  Inflation Unit of Measurement Country Code
# 0          Armenia  2018        2.5                   %          ARM
# 1          Armenia  2019        1.4                   %          ARM
# 2          Armenia  2020        1.2                   %          ARM
# 3          Armenia  2021        7.2                   %          ARM
# 4          Armenia  2022        8.6                   %          ARM
# ..             ...   ...        ...                 ...          ...
# 311        Vanuatu  2020        5.3                   %          VUT
# 312        Vanuatu  2021        2.3                   %          VUT
# 313        Vanuatu  2022        4.8                   %          VUT
# 314        Vanuatu  2023        4.0                   %          VUT
# 315        Vanuatu  2024        3.0                   %          VUT
#
# [316 rows x 5 columns]

# %%
inflation = inflation.drop(columns='Unit of Measurement')

# %%
inflation
# Out:
#     RegionalMember  Year  Inflation Country Code
# 0          Armenia  2018        2.5          ARM
# 1          Armenia  2019        1.4          ARM
# 2          Armenia  2020        1.2          ARM
# 3          Armenia  2021        7.2          ARM
# 4          Armenia  2022        8.6          ARM
# ..             ...   ...        ...          ...
# 311        Vanuatu  2020        5.3          VUT
# 312        Vanuatu  2021        2.3          VUT
# 313        Vanuatu  2022        4.8          VUT
# 314        Vanuatu  2023        4.0          VUT
# 315        Vanuatu  2024        3.0          VUT
#
# [316 rows x 4 columns]

# %%
inflation.to_csv('inflation.csv')

# %%
sns.lineplot(inflation[inflation['RegionalMember']=='Pakistan'],x='Year',y='Inflation')
# Out:
# <Axes: xlabel='Year', ylabel='Inflation'>

# %%
inflation.Year.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
inflation.groupby('Year')['Inflation'].sum()['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Economy Report/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 inflation.groupby('Year')['Inflation'].sum()['index']
#
# ...

# %%
list(d.values())
# Out:
# [np.float64(150.4),
#  np.float64(147.9),
#  np.float64(141.6),
#  np.float64(181.0),
#  np.float64(374.8),
#  np.float64(305.3),
#  np.float64(197.9)]
